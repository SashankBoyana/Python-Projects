# %%
import pandas as pd
import numpy as np
import cv2
import os

# %%
import os
test_path = "/Users/shanks/Downloads/test_set"

# %%
train_path = "/Users/shanks/Downloads/training_set"

# %%
IMG_SIZE = 64

# %%
train_path = "/Users/shanks/Downloads/training_set"

X = []
Y = []

labels = os.listdir(train_path)

for label_index, label in enumerate(labels):
    folder_path = os.path.join(train_path, label)

    for file in os.listdir(folder_path):
        img_path = os.path.join(folder_path, file)

        img = cv2.imread(img_path)
        if img is None:
            continue
        img = cv2.resize(img, (64,64))

        X.append(img)
        Y.append(label_index)

# %%
test_path = "/Users/shanks/Downloads/test_set"

X = []
Y = []


labels = os.listdir(train_path)

for label_index, label in enumerate(labels):
    folder_path = os.path.join(test_path, label)

    for file in os.listdir(folder_path):
        img_path = os.path.join(folder_path, file)

        img = cv2.imread(img_path)
        if img is None:
            continue
        img = cv2.resize(img, (64,64))

        X.append(img)
        Y.append(label_index)

# %%
X = np.array(X) / 255.0
Y = np.array(Y).reshape(1, -1)

# %%
input_size = 64 * 64 * 3

# %%
output_size = 1

# %%
X = X.reshape(X.shape[0], -1)
X = X.T

# %%
import numpy as np

input_size = 12288
hidden1 = 256
hidden2 = 128
output_size = 1

W1 = np.random.randn(256, 12288) * 0.01
b1 = np.zeros((hidden1,1))

W2 = np.random.randn(hidden2, hidden1) * 0.01
b2 = np.zeros((hidden2,1))

W3 = np.random.randn(output_size, hidden2) * 0.01
b3 = np.zeros((output_size,1))

# %%
def relu(x):
    return np.maximum(0,x)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
Z1 = np.dot(W1, X) + b1
A1 = np.maximum(0, Z1)

Z2 = np.dot(W2, A1) + b2
A2 = np.maximum(0, Z2)

Z3 = np.dot(W3, A2) + b3
A3 = 1 / (1 + np.exp(-Z3))

# %%
m = Y.shape[1]
loss = - (1/m) * np.sum(
    Y * np.log(A3 + 1e-8) +
    (1 - Y) * np.log(1 - A3 + 1e-8)
)

# %%
dZ3 = A3 - Y
dW3 = (1/m) * np.dot(dZ3, A2.T)
db3 = (1/m) * np.sum(dZ3, axis=1, keepdims=True)

dA2 = np.dot(W3.T, dZ3)
dZ2 = dA2 * (A2 > 0)

dW2 = (1/m) * np.dot(dZ2, A1.T)
db2 = (1/m) * np.sum(dZ2, axis=1, keepdims=True)

dA1 = np.dot(W2.T, dZ2)
dZ1 = dA1 * (A1 > 0)

dW1 = (1/m) * np.dot(dZ1, X.T)
db1 = (1/m) * np.sum(dZ1, axis=1, keepdims=True)

# %%
lr = 0.01
W1 -= lr * dW1
b1 -= lr * db1
W2 -= lr * dW2
b2 -= lr * db2
W3 -= lr * dW3
b3 -= lr * db3

# %%
for epoch in range(4000):

    Z1 = np.dot(W1, X) + b1
    A1 = np.maximum(0, Z1)

    Z2 = np.dot(W2, A1) + b2
    A2 = np.maximum(0, Z2)

    Z3 = np.dot(W3, A2) + b3
    A3 = 1 / (1 + np.exp(-Z3))

    m = Y.shape[1]
    loss = - (1/m) * np.sum(
        Y * np.log(A3 + 1e-8) +
        (1 - Y) * np.log(1 - A3 + 1e-8)
    )

    dZ3 = A3 - Y
    dW3 = (1/m) * np.dot(dZ3, A2.T)
    db3 = (1/m) * np.sum(dZ3, axis=1, keepdims=True)

    dA2 = np.dot(W3.T, dZ3)
    dZ2 = dA2 * (A2 > 0)

    dW2 = (1/m) * np.dot(dZ2, A1.T)
    db2 = (1/m) * np.sum(dZ2, axis=1, keepdims=True)

    dA1 = np.dot(W2.T, dZ2)
    dZ1 = dA1 * (A1 > 0)

    dW1 = (1/m) * np.dot(dZ1, X.T)
    db1 = (1/m) * np.sum(dZ1, axis=1, keepdims=True)

    lr = 0.01
    W1 -= lr * dW1
    b1 -= lr * db1
    W2 -= lr * dW2
    b2 -= lr * db2
    W3 -= lr * dW3
    b3 -= lr * db3

    if epoch % 100 == 0:
        print("Epoch:", epoch, "Loss:", loss)
# Out:
# Epoch: 0 Loss: 0.552000450170939
# Epoch: 100 Loss: 0.5429003594222978
# Epoch: 200 Loss: 0.534681785947886
# Epoch: 300 Loss: 0.526754712569695
# Epoch: 400 Loss: 0.5164441705202807
# Epoch: 500 Loss: 0.5061220440628926
# Epoch: 600 Loss: 0.4983002069805271
# Epoch: 700 Loss: 0.4677069796522548
# Epoch: 800 Loss: 0.6466502089233436
# Epoch: 900 Loss: 0.4125947101863249
# Epoch: 1000 Loss: 0.44689427289437167
# Epoch: 1100 Loss: 0.3707348550296469
# Epoch: 1200 Loss: 0.6086844479161714
# Epoch: 1300 Loss: 0.4461751395908997
# Epoch: 1400 Loss: 0.3386187987729997
# Epoch: 1500 Loss: 0.29099835673096275
# Epoch: 1600 Loss: 0.42872300058922314
# Epoch: 1700 Loss: 0.2826352466209649
# Epoch: 1800 Loss: 0.41223468960496407
# Epoch: 1900 Loss: 0.7406579434696565
# Epoch: 2000 Loss: 1.4183405973839396
# Epoch: 2100 Loss: 0.3500519628819757
# Epoch: 2200 Loss: 1.2961779591128757
# Epoch: 2300 Loss: 0.203904987776691
# Epoch: 2400 Loss: 0.26041298451384315
# Epoch: 2500 Loss: 0.16657643813680284
# Epoch: 2600 Loss: 0.292948130215891
# Epoch: 2700 Loss: 0.1810538198035285
# Epoch: 2800 Loss: 0.37034600728376044
# Epoch: 2900 Loss: 0.13906304201588607
# Epoch: 3000 Loss: 0.11973048134340408
# Epoch: 3100 Loss: 0.1091409688578942
# Epoch: 3200 Loss: 0.10399052301400905
# Epoch: 3300 Loss: 0.11224147868245973
# Epoch: 3400 Loss: 1.672285443992913
# Epoch: 3500 Loss: 0.10322320115566717
# Epoch: 3600 Loss: 0.10091056113766365
# Epoch: 3700 Loss: 0.08307686831403897
# Epoch: 3800 Loss: 0.17559799065635545
# Epoch: 3900 Loss: 0.05838363044486071

# %%
predictions = (A3 > 0.5).astype(int)
accuracy = np.mean(predictions == Y)
print("Accuracy:", accuracy * 100, "%")
# Out:
# Accuracy: 99.5551161641127 %
